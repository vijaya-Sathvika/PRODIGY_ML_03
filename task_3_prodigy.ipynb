# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaya-Sathvika/PRODIGY_ML_03/blob/main/task_3_prodigy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
data=pd.read_csv("/content/archive (16).zip")

# %%
data
# Out:
#                                            Product Name  Product ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Listing Price  Sale Price  Discount                    Brand  \
# 0             14999        7499        50  Adidas Adidas ORIGINALS
# ...

# %%
data.head()
# Out:
#                                         Product Name Product ID  \
# 0  Women's adidas Originals NMD_Racer Primeknit S...     AH2430
# 1               Women's adidas Originals Sleek Shoes     G27341
# 2                  Women's adidas Swim Puka Slippers     CM0081
# 3   Women's adidas Sport Inspired Questar Ride Shoes     B44832
# 4           Women's adidas Originals Taekwondo Shoes     D98205
#
#    Listing Price  Sale Price  Discount                    Brand  \
# 0          14999        7499        50  Adidas Adidas ORIGINALS
# 1           7599        3799        50         Adidas ORIGINALS
# 2            999         599        40        Adidas CORE / NEO
# 3           6999        3499        50        Adidas CORE / NEO
# 4           7999        3999        50         Adidas ORIGINALS
#
#                                          Description  Rating  Reviews  \
# 0  Channeling the streamlined look of an '80s rac...     4.8       41
# ...

# %%
data.tail()
# Out:
#                               Product Name  Product ID  Listing Price  \
# 3263                    Air Jordan 8 Retro  CI1236-100          15995
# 3264            Nike Phantom Venom Club IC  AO0578-717           4995
# 3265  Nike Mercurial Superfly 7 Academy TF  AT7978-414           8495
# 3266                       Nike Air Max 98  AH6799-300              0
# 3267                        Nike P-6000 SE  CJ9585-600           8995
#
#       Sale Price  Discount Brand  \
# 3263       12797         0  Nike
# 3264        3497         0  Nike
# 3265        5947         0  Nike
# 3266       16995         0  Nike
# 3267        6297         0  Nike
#
#                                             Description  Rating  Reviews  \
# 3263  The Air Jordan 8 Retro recaptures the memorabl...     5.0        1
# 3264  The Nike Phantom Venom Club IC is engineered f...     0.0        0
# 3265  The soft upper of the Nike Mercurial Superfly ...     5.0        1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3268 entries, 0 to 3267
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product Name   3268 non-null   object
#  1   Product ID     3268 non-null   object
#  2   Listing Price  3268 non-null   int64
#  3   Sale Price     3268 non-null   int64
#  4   Discount       3268 non-null   int64
#  5   Brand          3268 non-null   object
#  6   Description    3265 non-null   object
#  7   Rating         3268 non-null   float64
#  8   Reviews        3268 non-null   int64
#  9   Last Visited   3268 non-null   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 255.4+ KB

# %%
data.drop("Description",axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# Product Name     0
# Product ID       0
# Listing Price    0
# Sale Price       0
# Discount         0
# Brand            0
# Rating           0
# Reviews          0
# Last Visited     0
# dtype: int64

# %%
data
# Out:
#                                            Product Name  Product ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Listing Price  Sale Price  Discount                    Brand  Rating  \
# ...

# %%
x_train=data[['Listing Price','Sale Price']]
x_train.plot.scatter(x="Listing Price", y="Sale Price",
                     c="darkred", marker="x", alpha=.5)
# Out:
# <Axes: xlabel='Listing Price', ylabel='Sale Price'>

# %%
from sklearn.cluster import KMeans
n_clusters=int(input())
model = KMeans(n_clusters)
model.fit(x_train)
# Out:
# 8
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans()

# %%
centroids = model.cluster_centers_
clusters = model.labels_
print(centroids)
print(clusters)
# Out:
# [[ 5.38944515e+03  3.20267199e+03]
#  [ 1.65092283e+04  1.28029772e+04]
#  [-3.09228199e-11  8.83453488e+03]
#  [ 1.21442368e+04  8.08522368e+03]
#  [ 1.36424205e-11  1.66148973e+04]
#  [ 7.88543855e+03  5.39002771e+03]
#  [ 2.32390000e+04  2.32390000e+04]
#  [ 2.79701013e+03  1.99740253e+03]]
# [3 5 7 ... 5 4 5]

# %%
from sklearn.metrics import silhouette_score
from scipy.spatial import distance # To calculate distances
import matplotlib.pyplot as plt
sse = {}
for k in range(1,10):
    model = KMeans(n_clusters=k)
    model.fit(x_train)
    # y_kmeans = kmeans.predict(X)
    sse[k] = model.inertia_
    print("For cluster = {}, WCSS is {}".format(k, sse[k]))

plt.figure()
plt.plot(list(sse.keys()),list(sse.values()),linewidth=3, color = 'Yellow', marker='o', markerfacecolor='green')
plt.xlabel("Number of Cluster")
plt.ylabel("WCSS")
plt.title("Elbow Method")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# For cluster = 1, WCSS is 133144563080.12112
# For cluster = 2, WCSS is 74818103864.79875
# For cluster = 3, WCSS is 42304655958.81266
# For cluster = 4, WCSS is 30130194970.598305
# For cluster = 5, WCSS is 23153538349.19256
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
ss = {}

for k in range(2,10):
    model = KMeans(n_clusters=k)
    model.fit(x_train)
    label = model.labels_
    sil_coeff = silhouette_score(x_train,label,metric = 'euclidean')
    ss[k] = sil_coeff
    print('For cluster= {}, Silhouette Coefficient is {}'.format(k,sil_coeff))

plt.figure()
plt.plot(list(ss.keys()),list(ss.values()), linewidth=3, color = 'Yellow', marker='o', markerfacecolor='green')
plt.xlabel("Number of Cluster")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Analysis")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# For cluster= 2, Silhouette Coefficient is 0.5220509000577862
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# For cluster= 3, Silhouette Coefficient is 0.5803203218863692
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# For cluster= 4, Silhouette Coefficient is 0.4759950697863503
# ...

# %%
# !pip install scikit-learn-extra
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.7 MB/s eta 0:00:00
# ...

# %%
from sklearn_extra.cluster import KMedoids

# %%
Medoids = KMedoids(n_clusters=3, random_state=0, method='pam', init='k-medoids++')

# %%
Medoids.fit(x_train)
print(Medoids.labels_)
# Out:
# [0 2 2 ... 2 1 0]

# %%
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy
plt.figure(figsize=(17,10))
plt.title('Dendrogram')
#plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'ward'))
plt.show()

# %%
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy
plt.figure(figsize=(17,10))
plt.title('Dendrogram')
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'single'))
plt.show()

# %%
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy
plt.figure(figsize=(17,10))
plt.title('Dendrogram')
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'complete'))
plt.show()

# %%
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy
plt.figure(figsize=(17,10))
plt.title('Dendrogram')
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'average'))
plt.show()

# %%
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy
plt.figure(figsize=(17,10))
plt.title('Dendrogram')
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'centroid'))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Dendrogram')
plt.hlines(y=100,xmin=0,xmax=7000,lw=3,linestyles='--')
plt.text(x=900,y=110,s='Horizontal line crossing 2 vertical lines',fontsize=20)
plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'ward'))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Dendrogram')
plt.hlines(y=3.5,xmin=0,xmax=7000,lw=3,linestyles='--')
plt.text(x=900,y=3.5,s='Horizontal line crossing 2 vertical lines',fontsize=20)
plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'single'))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Dendrogram')
plt.hlines(y=25,xmin=0,xmax=7000,lw=3,linestyles='--')
plt.text(x=900,y=25,s='Horizontal line crossing 2 vertical lines',fontsize=20)
plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'complete'))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Dendrogram')
plt.hlines(y=7.5,xmin=0,xmax=7000,lw=3,linestyles='--')
plt.text(x=900,y=7.5,s='Horizontal line crossing 5 vertical lines',fontsize=20)
plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'average'))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Dendrogram')
plt.hlines(y=8,xmin=0,xmax=7000,lw=3,linestyles='--')
plt.text(x=900,y=8,s='Horizontal line crossing 4 vertical lines',fontsize=20)
plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'centroid'))
plt.show()

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.9, min_samples=2)
labels = dbscan.fit_predict(x_train)
labels
# Out:
# array([  0,   1,   2, ..., 187, 154, 207])

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train.iloc[:,0], x_train.iloc[:,1],c=labels,cmap='viridis')
plt.title("DBSCAN Clustering")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)
print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)
# Out:
# Estimated number of clusters: 217
# Estimated number of noise points: 58

# %%
from sklearn.metrics import silhouette_score
sil_coeff=silhouette_score(x_train,dbscan.labels_)
print(sil_coeff)
# Out:
# 0.9654367851415961

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
x_train_pca=pca.fit_transform(x_train)

# %%
pca_kmeans=KMeans(n_clusters=3)
pca_kmeans.fit(x_train_pca)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
# Extract the centroids and the clusters.
centroids_kmeans = pca_kmeans.cluster_centers_
clusters_kmeans= pca_kmeans.labels_
print(centroids_kmeans)
print(clusters_kmeans)
# Out:
# [[ 8144.81478031  -946.14360756]
#  [-2073.77845613  8749.95484116]
#  [-2165.72533464 -1242.04933366]]
# [0 2 2 ... 2 1 2]

# %%
from sklearn.metrics import silhouette_score
ss = {}

for k in range(2,10):
    model = KMeans(n_clusters=k)
    model.fit(x_train_pca)
    label = model.labels_
    sil_coeff = silhouette_score(x_train_pca,label,metric = 'euclidean')
    ss[k] = sil_coeff
    print('For cluster= {}, Silhouette Coefficient is {}'.format(k,sil_coeff))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# For cluster= 2, Silhouette Coefficient is 0.5220509000480498
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# For cluster= 3, Silhouette Coefficient is 0.5803203218549366
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# For cluster= 4, Silhouette Coefficient is 0.47529916549190854
# ...

# %%
Medoids_pca = KMedoids(n_clusters=3, random_state=0, method='pam', init='k-medoids++')

# %%
Medoids_pca.fit(x_train_pca)
print(Medoids_pca.labels_)
# Out:
# [0 2 2 ... 2 1 0]
# /usr/local/lib/python3.10/dist-packages/sklearn_extra/cluster/_k_medoids.py:297: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(

# %%
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy
plt.figure(figsize=(17,10))
plt.title('Dendrogram')
#plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(x_train_pca, method = 'ward'))
plt.show()

# %%
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy
plt.figure(figsize=(17,10))
plt.title('Dendrogram')
dendrogram = sch.dendrogram(sch.linkage(x_train_pca, method = 'single'))
plt.show()

# %%
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy
plt.figure(figsize=(17,10))
plt.title('Dendrogram')
dendrogram = sch.dendrogram(sch.linkage(x_train_pca, method = 'complete'))
plt.show()

# %%
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy
plt.figure(figsize=(17,10))
plt.title('Dendrogram')
dendrogram = sch.dendrogram(sch.linkage(x_train_pca, method = 'average'))
plt.show()

# %%
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster import hierarchy
plt.figure(figsize=(17,10))
plt.title('Dendrogram')
dendrogram = sch.dendrogram(sch.linkage(x_train_pca, method = 'centroid'))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Dendrogram')
plt.hlines(y=100,xmin=0,xmax=7000,lw=3,linestyles='--')
plt.text(x=900,y=110,s='Horizontal line crossing 2 vertical lines',fontsize=20)
plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'ward'))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Dendrogram')
plt.hlines(y=3.5,xmin=0,xmax=7000,lw=3,linestyles='--')
plt.text(x=900,y=3.5,s='Horizontal line crossing 2 vertical lines',fontsize=20)
plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'single'))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Dendrogram')
plt.hlines(y=27,xmin=0,xmax=7000,lw=3,linestyles='--')
plt.text(x=900,y=27,s='Horizontal line crossing 2 vertical lines',fontsize=20)
plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'complete'))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Dendrogram')
plt.hlines(y=11,xmin=0,xmax=7000,lw=3,linestyles='--')
plt.text(x=900,y=11,s='Horizontal line crossing 3 vertical lines',fontsize=20)
plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'average'))
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Dendrogram')
plt.hlines(y=10,xmin=0,xmax=7000,lw=3,linestyles='--')
plt.text(x=900,y=9,s='Horizontal line crossing 2 vertical lines',fontsize=20)
plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(x_train, method = 'centroid'))
plt.show()

# %%
from sklearn.cluster import DBSCAN
dbscan_pca = DBSCAN(eps=0.9, min_samples=2)
labels_pca= dbscan_pca.fit_predict(x_train_pca)
labels_pca
# Out:
# array([  0,   1,   2, ..., 187, 154, 207])
